# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.spatial import KDTree
import cv2
import logging
from math import cos, sin, atan2, sqrt
import os

# %%
scan = pd.read_csv("files/scan.csv")
print(scan.head())
# Out:
#                   t_ns  angle_min  angle_inc   r0   r1   r2   r3   r4   r5  \
# 0  1771970259546107435      -3.14   0.017493  inf  inf  inf  inf  inf  inf
# 1  1771970259548293604      -3.14   0.017493  inf  inf  inf  inf  inf  inf
# 2  1771970259924411242      -3.14   0.017493  inf  inf  inf  inf  inf  inf
# 3  1771970260371970673      -3.14   0.017493  inf  inf  inf  inf  inf  inf
# 4  1771970260548317064      -3.14   0.017493  inf  inf  inf  inf  inf  inf
#
#     r6  ...      r350      r351      r352      r353      r354      r355  \
# 0  inf  ...  3.154634  3.146277  3.138921  3.132555  3.127170  3.122758
# 1  inf  ...  3.154655  3.146296  3.138940  3.132575  3.127189  3.122777
# 2  inf  ...  3.154647  3.146288  3.138932  3.132566  3.127182  3.122769
# 3  inf  ...  3.154612  3.146254  3.138897  3.132531  3.127146  3.122733
# 4  inf  ...  3.154605  3.146246  3.138889  3.132523  3.127138  3.122725
#
#        r356      r357      r358  r359
# 0  3.119312  3.116825  3.640858   inf
# 1  3.119330  3.116844  3.640188   inf
# 2  3.119322  3.116835  3.639570   inf
# 3  3.119286  3.116800  3.638992   inf
# 4  3.119278  3.116791  3.638376   inf
#
# [5 rows x 363 columns]

# %%
odom = pd.read_csv("files/odom.csv")
print(odom.head())
# Out:
#                   t_ns         x         y       yaw        vx        wz
# 0  1771970259546758904 -0.259115  0.012268 -0.094643 -0.000081 -0.000036
# 1  1771970259548513561 -0.259147  0.012271 -0.094644 -0.000081 -0.000036
# 2  1771970259548558973 -0.259121  0.012268 -0.094645 -0.000081 -0.000036
# 3  1771970259549006889 -0.259153  0.012271 -0.094647 -0.000081 -0.000036
# 4  1771970259578917270 -0.259127  0.012269 -0.094648 -0.000081 -0.000036

# %%
tf = pd.read_csv("files/tf.csv")
tf = tf[(tf["child"] == "robot1/base_link") & (tf["parent"] == "robot1/odom")]
print(tf.head())
# Out:
#                    t_ns       parent             child        tx        ty  \
# 0   1771970259762743088  robot1/odom  robot1/base_link -0.259159  0.012272
# 1   1771970259911077874  robot1/odom  robot1/base_link -0.259133  0.012269
# 9   1771970260053355975  robot1/odom  robot1/base_link -0.259165  0.012272
# 10  1771970260287224960  robot1/odom  robot1/base_link -0.259138  0.012270
# 11  1771970260389589039  robot1/odom  robot1/base_link -0.259170  0.012273
#
#      tz       yaw
# 0   0.0 -0.094649
# 1   0.0 -0.094650
# 9   0.0 -0.094652
# 10  0.0 -0.094653
# 11  0.0 -0.094654

# %%
obstacles = pd.read_csv("files/map_obstacles.csv")
print(obstacles.head())
# Out:
#                   t_ns         x         y  row  col  occupancy
# 0  1771970261302923084 -9.274242 -10.88494  345  118        100
# 1  1771970261302923084 -9.235772 -10.88494  345  119        100
# 2  1771970261302923084 -9.197302 -10.88494  345  120        100
# 3  1771970261302923084 -9.158832 -10.88494  345  121        100
# 4  1771970261302923084 -9.120362 -10.88494  345  122        100

# %%
# plot obstacles
obs = obstacles[obstacles["t_ns"] == 1771970261302923084]
plt.scatter(obs["x"], obs["y"], c="red", label="Obstacles")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# %%
def get_scan_for_odom(t_ns):
    # find the closest scan in scan
    idx = (np.abs(scan["t_ns"] - t_ns)).argmin()
    print(f"Closest scan has a delta of {(scan['t_ns'][idx] - t_ns) / 1e9} seconds")
    return scan.iloc[idx]

# %%
def get_obstacles_for_odom(t_ns):
    # find the closest obstacles in obstacles
    idx = (np.abs(obstacles["t_ns"] - t_ns)).argmin()
    print(f"Closest obstacles has a delta of {(obstacles['t_ns'][idx] - t_ns) / 1e9} seconds")
    return obstacles[obstacles["t_ns"] == obstacles["t_ns"][idx]]

# %%
get_obstacles_for_odom(1771970261302923084)
# Out:
# Closest obstacles has a delta of 0.0 seconds
#                       t_ns         x          y  row  col  occupancy
# 0      1771970261302923084 -9.274242 -10.884940  345  118        100
# 1      1771970261302923084 -9.235772 -10.884940  345  119        100
# 2      1771970261302923084 -9.197302 -10.884940  345  120        100
# 3      1771970261302923084 -9.158832 -10.884940  345  121        100
# 4      1771970261302923084 -9.120362 -10.884940  345  122        100
# ...                    ...       ...        ...  ...  ...        ...
# 31990  1771970261302923084  9.383773  10.850685  910  603        100
# 31991  1771970261302923084  9.422243  10.850685  910  604        100
# 31992  1771970261302923084  9.460713  10.850685  910  605        100
# 31993  1771970261302923084  9.499183  10.850685  910  606        100
# 31994  1771970261302923084  9.537653  10.850685  910  607        100
#
# [31995 rows x 6 columns]

# %%
map_info = pd.read_csv("files/map_info.csv")
print(map_info.head())
# Out:
#                   t_ns                        image_file  resolution  width  \
# 0  1771970261302923084  map_0001_1771970261302923084.png    0.038470    780
# 1  1771970262676835950  map_0002_1771970262676835950.png    0.038477    780
# 2  1771970264338306300  map_0003_1771970264338306300.png    0.038477    780
# 3  1771970275057061199  map_0004_1771970275057061199.png    0.038361    779
# 4  1771970276683722140  map_0005_1771970276683722140.png    0.038375    779
#
#    height   origin_x   origin_y
# 0    1313 -13.832953 -24.176372
# 1    1313 -13.832458 -24.179622
# 2    1313 -13.833145 -24.180321
# 3    1313 -13.785823 -24.102653
# 4    1313 -13.788734 -24.110678

# %%
def get_odom(t_ns):
    match_odom = odom[odom["t_ns"] == t_ns]
    x = float(match_odom["x"].values[0])
    y = float(match_odom["y"].values[0])
    theta = float(match_odom["yaw"].values[0])
    return x,y,theta

# %%
def get_odom_transform(x, y, theta):
    R = np.array([[np.cos(theta), -np.sin(theta)],
                  [np.sin(theta),  np.cos(theta)]], dtype=float)
    t = np.array([x, y-4], dtype=float)
    return R, t

# %%
def get_point_from_scan(t_ns):
    match_scan = get_scan_for_odom(t_ns)
    points = []
    angle = match_scan["angle_min"]

    # loop on match_scan columns starting from the 4th column and compute the x and y coordinates of the points in the scan and store them in a list
    for r in match_scan[3:].values:
        if np.isnan(r) or np.isinf(r):
            angle += match_scan["angle_inc"]
            continue

        x = r * cos(angle)
        y = r* sin(angle)

        points.append([x,y])

        angle += match_scan["angle_inc"]

    return (np.array(points))

# %%
def compute_transformation(P, Q):
        p_mean = np.mean(P,axis=0)
        q_mean = np.mean(Q, axis=0)

        P_centered = P - p_mean
        Q_centered = Q - q_mean

        H = P_centered.T @ Q_centered

        U, _, Vt = np.linalg.svd(H)
        V = Vt.T

        R = V @ U.T
        if np.linalg.det(R) < 0:
            S = np.diag([1, -1])
            R = V @ S @ U.T
        
        t = q_mean - R @ p_mean

        return R, t

# %%
def get_map_obstacles_for_odom(t_ns):

    image_files = os.listdir("files/map_images")
    t_ns_list = []
    for image_file in image_files:
        t = int(image_file.split("_")[2].split(".")[0])
        # store t_ns and corresponding image file in a list of tuples
        t_ns_list.append({'t':t, 'image_file': image_file})

    idx = (np.abs(np.array([d['t'] for d in t_ns_list]) - t_ns)).argmin()
    print(f"Closest map is {t_ns_list[idx]['image_file']} has a delta of {(t_ns_list[idx]['t'] - t_ns) / 1e9} seconds")
    map = cv2.imread(f"files/map_images/{t_ns_list[idx]['image_file']}",cv2.IMREAD_GRAYSCALE)
    _, bw = cv2.threshold(map, 200, 255, cv2.THRESH_BINARY_INV)

    # (optional) clean tiny noise
    kernel = np.ones((3, 3), np.uint8)
    bw = cv2.morphologyEx(bw, cv2.MORPH_OPEN, kernel, iterations=1)

    contours, _ = cv2.findContours(bw, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # white canvas
    out = np.full_like(map, 255)

    # draw ALL contours
    cv2.drawContours(out, contours, -1, 0, thickness=1)

    resolution = map_info[map_info['t_ns'] == t_ns_list[idx]['t']]['resolution'].values[0]
    origin_x = map_info[map_info['t_ns'] == t_ns_list[idx]['t']]['origin_x'].values[0]
    origin_y = map_info[map_info['t_ns'] == t_ns_list[idx]['t']]['origin_y'].values[0]
    points = []

    # get x and y of none black pixels in out and convert them to world coordinates
    for i in range(out.shape[0]):
        for j in range(out.shape[1]):
            if out[i][j] != 255:  # if pixel is not white (i.e., is black)
                x = origin_x + j * resolution
                y = origin_y + (out.shape[0]-i-1) * resolution
                points.append([x,y])

    return np.array(points)

# %%
get_map_obstacles_for_odom(1771970261302923084)
# Out:
# Closest map is map_0001_1771970261302923084.png has a delta of 0.0 seconds
# array([[  9.01830668,  10.83145042],
#        [  9.05677682,  10.83145042],
#        [  9.09524695,  10.83145042],
#        ...,
#        [ -8.63948489, -10.90417537],
#        [ -8.60101475, -10.90417537],
#        [ -8.56254462, -10.90417537]], shape=(3634, 2))

# %%
map = get_map_obstacles_for_odom(1771970261302923084)
# plot image of map and points of obstacles
plt.scatter(map[:,0], map[:,1], c="red", label="Obstacles")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()
# Out:
# Closest map is map_0001_1771970261302923084.png has a delta of 0.0 seconds

# %%
height = map_info[map_info['t_ns'] == 1771970261302923084]['height'].values[0]  
print(height)
# Out:
# 1313

# %%
def icp_pose(source, target,R_od,t_od, max_iterations=50, plot=False):

    R_total = np.eye(2)
    t_total = np.zeros(2)
    src = (R_od @ source.T).T + t_od

    tree = KDTree(target)

    mean_error = float("inf")
    for i in range(max_iterations):
        
        distances, indices = tree.query(src)
        valid_mask = distances < 2
        src_matched = src[valid_mask]
        target_matched = target[indices[valid_mask]]

        R,t = compute_transformation(src_matched, target_matched)
        src = (R @ src.T).T + t

        prev_mean_error = mean_error

        # Recompute error AFTER applying the update
        distances2, indices2 = tree.query(src)
        valid_mask2 = distances2 < 2
        if np.count_nonzero(valid_mask2) == 0:
            print("No valid matches after update, stopping.")
            break

        
        mean_error = float(np.mean(distances2[valid_mask2]))

        if mean_error > prev_mean_error:
            break

        R_total = R @ R_total
        t_total = R @ t_total + t
    
        R_icp = R_total @ R_od
        t_icp = R_total @ t_od + t_total
        

        x_icp = t_icp[0]
        y_icp = t_icp[1]
        theta_icp = atan2(R_icp[1,0], R_icp[0,0])
        if i==0:
            # store initial icp pose and source for later plotting
            x_icp_initial = x_icp
            y_icp_initial = y_icp
            theta_icp_initial = theta_icp
            source_initial = src.copy()
            mean_error_initial = mean_error

    print(f'mean_error: {mean_error} after {i} iterations')

    if plot ==True:

        # plot side by side initial and final sources and poses
        plt.figure(figsize=(10,5))
        plt.subplot(1,2,1)
        plt.arrow(x_icp_initial, y_icp_initial, 0.5*np.cos(theta_icp_initial), 0.5*np.sin(theta_icp_initial), head_width=0.2, head_length=0.2, fc='green', ec='green') 
        plt.scatter(x_icp_initial, y_icp_initial, c="green", label="ICP Initial Position", s=30)
        plt.arrow(t_od[0], t_od[1], 0.5*np.cos(atan2(R_od[1,0], R_od[0,0])), 0.5*np.sin(atan2(R_od[1,0], R_od[0,0])), head_width=0.2, head_length=0.2, fc='blue', ec='blue')  
        plt.scatter(t_od[0], t_od[1], c="blue", label="Odom Position", s=30)
        plt.scatter(target[:,0], target[:,1], c="black", label="Map Obstacles", s=0.3)
        plt.scatter(source_initial[:,0], source_initial[:,1], c="red", label="Initial Scan Points", s=1)
        plt.title(f"Initial iteration: ICP and Odometry Positions,\n mean error: {mean_error_initial:.4f}")
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.legend()
        plt.grid()

        plt.subplot(1,2,2)
            # plot icp pose as a blue arrow
        plt.arrow(x_icp, y_icp, 0.5*np.cos(theta_icp), 0.5*np.sin(theta_icp), head_width=0.2, head_length=0.2, fc='green', ec='green') 
        plt.scatter(x_icp, y_icp, c="green", label="ICP Final Position", s=30)
        plt.arrow(t_od[0], t_od[1], 0.5*np.cos(atan2(R_od[1,0], R_od[0,0])), 0.5*np.sin(atan2(R_od[1,0], R_od[0,0])), head_width=0.2, head_length=0.2, fc='blue', ec='blue')  
        plt.scatter(t_od[0], t_od[1], c="blue", label="Odom Position", s=30)
        plt.scatter(target[:,0], target[:,1], c="black", label="Map Obstacles", s=0.3)
        plt.scatter(src[:,0], src[:,1], c="red", label="Scan Points", s=1)
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.title(f"Final Iteration {i}: ICP and Odometry Positions,\n mean error: {mean_error:.4f}")
        plt.legend()
        plt.grid()
        plt.show()    

    return {"x": x_icp, "y": y_icp, "theta": theta_icp, "mean_error": mean_error, "initial_x": x_icp_initial, "initial_y": y_icp_initial, "initial_theta": theta_icp_initial, "mean_error_initial": mean_error_initial, "odom_x": t_od[0], "odom_y": t_od[1], "odom_theta": atan2(R_od[1,0], R_od[0,0])}

# %%
icp_results=[]
for t_ns in odom["t_ns"].values:
    target = get_map_obstacles_for_odom(t_ns)
    source = get_point_from_scan(t_ns)
    x_od,y_od,theta_od = get_odom(t_ns)
    R_od, t_od = get_odom_transform(x_od, y_od, theta_od)
    icp_result = icp_pose(source, target,R_od,t_od)
    icp_results.append(icp_result)
    print(f"Odometry pose in world: x={t_od[0]}, y={t_od[1]}, theta={atan2(R_od[1,0], R_od[0,0])}")
    print(f"ICP pose in world: x={icp_result['x']}, y={icp_result['y']}, theta={icp_result['theta']}")
icp_result_df = pd.DataFrame(icp_results)
icp_result_df.to_csv("icp_results.csv", index=False)
# Out:
# Closest map is map_0001_1771970261302923084.png has a delta of 1.75616418 seconds
# Closest scan has a delta of -0.000651469 seconds
# mean_error: 0.12100208615906684 after 7 iterations
# Odometry pose in world: x=-0.2591152882920883, y=-3.987732419811621, theta=-0.0946427081665465
# ICP pose in world: x=-0.11967703341011926, y=-3.988703748092749, theta=0.048658388063229495
# Closest map is map_0001_1771970261302923084.png has a delta of 1.754409523 seconds
# Closest scan has a delta of -0.000219957 seconds
# mean_error: 0.1210003544193843 after 7 iterations
# Odometry pose in world: x=-0.259147304380023, y=-3.987729380616852, theta=-0.0946443110206815
# ICP pose in world: x=-0.12002714625884109, y=-3.988739374544347, theta=0.0486144119306014
# Closest map is map_0001_1771970261302923084.png has a delta of 1.754364111 seconds
# Closest scan has a delta of -0.000265369 seconds
# mean_error: 0.12100035441938485 after 7 iterations
# Odometry pose in world: x=-0.2591210822486714, y=-3.987731869841677, theta=-0.0946452495725636
# ICP pose in world: x=-0.12002714625884042, y=-3.9887393745443482, theta=0.04861441193060117
# Closest map is map_0001_1771970261302923084.png has a delta of 1.753916195 seconds
# Closest scan has a delta of -0.000713285 seconds
# mean_error: 0.12100035441938545 after 7 iterations
# Odometry pose in world: x=-0.2591530990899228, y=-3.987728830493458, theta=-0.09464684222665819
# ICP pose in world: x=-0.12002714625884031, y=-3.9887393745443465, theta=0.048614411930601564
# Closest map is map_0001_1771970261302923084.png has a delta of 1.724005814 seconds
# Closest scan has a delta of -0.030623666 seconds
# mean_error: 0.12100035441938513 after 7 iterations
# Odometry pose in world: x=-0.2591268762018303, y=-3.987731319856954, theta=-0.0946477702892084
# ICP pose in world: x=-0.12002714625884087, y=-3.9887393745443482, theta=0.04861441193060118
# Closest map is map_0001_1771970261302923084.png has a delta of 1.609234459 seconds
# Closest scan has a delta of -0.145395021 seconds
# mean_error: 0.12100035441938531 after 7 iterations
# Odometry pose in world: x=-0.2591588925061989, y=-3.987728280478433, theta=-0.0946493529137431
# ICP pose in world: x=-0.12002714625884014, y=-3.9887393745443473, theta=0.04861441193060098
# Closest map is map_0001_1771970261302923084.png has a delta of 1.354907702 seconds
# Closest scan has a delta of -0.02360414 seconds
# mean_error: 0.12099881992801678 after 7 iterations
# Odometry pose in world: x=-0.2591326702935008, y=-3.9877307698441085, theta=-0.0946502708365279
# ICP pose in world: x=-0.12003603817229841, y=-3.9887441563678747, theta=0.048613630194187935
# Closest map is map_0001_1771970261302923084.png has a delta of 1.246308813 seconds
# Closest scan has a delta of -0.132203029 seconds
# mean_error: 0.12099881992801724 after 7 iterations
# Odometry pose in world: x=-0.2591646866688393, y=-3.9877277303782246, theta=-0.09465184384878111
# ICP pose in world: x=-0.12003603817229874, y=-3.988744156367874, theta=0.048613630194188046
# Closest map is map_0001_1771970261302923084.png has a delta of 1.009520703 seconds
# Closest scan has a delta of 0.078568292 seconds
# mean_error: 0.12099752424222361 after 7 iterations
# Odometry pose in world: x=-0.2591384644379592, y=-3.987730219811403, theta=-0.0946527519743049
# ICP pose in world: x=-0.12005812682057071, y=-3.988756039296519, theta=0.04861180794733382
# Closest map is map_0001_1771970261302923084.png has a delta of 0.878791662 seconds
# Closest scan has a delta of -0.052160749 seconds
# mean_error: 0.12099752424222336 after 7 iterations
# Odometry pose in world: x=-0.2591704806016107, y=-3.9877271802856162, theta=-0.09465431565185228
# ICP pose in world: x=-0.12005812682057027, y=-3.9887560392965202, theta=0.04861180794733454
# Closest map is map_0001_1771970261302923084.png has a delta of 0.852407723 seconds
# Closest scan has a delta of -0.078544688 seconds
# mean_error: 0.1209975242422226 after 7 iterations
# Odometry pose in world: x=-0.2591442586575659, y=-3.987729669756838, theta=-0.0946552143015743
# ICP pose in world: x=-0.12005812682057176, y=-3.9887560392965193, theta=0.048611807947334294
# Closest map is map_0001_1771970261302923084.png has a delta of 0.783332259 seconds
# Closest scan has a delta of 0.028726239 seconds
# mean_error: 0.12099602201137098 after 7 iterations
# Odometry pose in world: x=-0.2591762747447195, y=-3.987726630158913, theta=-0.09465676896483721
# ICP pose in world: x=-0.12006698947235772, y=-3.9887607431669925, theta=0.04861103153000725
# Closest map is map_0001_1771970261302923084.png has a delta of 0.741622745 seconds
# Closest scan has a delta of -0.012983275 seconds
# mean_error: 0.12099602201137118 after 7 iterations
# Odometry pose in world: x=-0.25915005292515, y=-3.987729119683106, theta=-0.0946576584469418
# ICP pose in world: x=-0.12006698947235828, y=-3.9887607431669916, theta=0.048611031530007294
# Closest map is map_0001_1771970261302923084.png has a delta of 0.676775585 seconds
# Closest scan has a delta of -0.077830435 seconds
# mean_error: 0.12099602201137005 after 7 iterations
# Odometry pose in world: x=-0.2591820688749529, y=-3.9877260800194057, theta=-0.0946592043746583
# ICP pose in world: x=-0.12006698947235861, y=-3.9887607431669907, theta=0.04861103153000802
# Closest map is map_0001_1771970261302923084.png has a delta of 0.611777192 seconds
# Closest scan has a delta of 0.039519946 seconds
# mean_error: 0.12099464707656059 after 7 iterations
# Odometry pose in world: x=-0.2591558472378745, y=-3.9877285695905913, theta=-0.0946600849815353
# ICP pose in world: x=-0.12007506118274552, y=-3.988765024312578, theta=0.04861032512887145
# Closest map is map_0001_1771970261302923084.png has a delta of 0.556741429 seconds
# Closest scan has a delta of -0.015515817 seconds
# mean_error: 0.12099464707656005 after 7 iterations
# Odometry pose in world: x=-0.2591878630814541, y=-3.987725529858724, theta=-0.09466162245145361
# ICP pose in world: x=-0.12007506118274586, y=-3.9887650243125763, theta=0.048610325128871444
# Closest map is map_0001_1771970261302923084.png has a delta of 0.497104383 seconds
# Closest scan has a delta of 0.052031521 seconds
# mean_error: 0.12099297400806039 after 7 iterations
# Odometry pose in world: x=-0.2591616415825034, y=-3.987728019480659, theta=-0.094662494461975
# ICP pose in world: x=-0.12007103489205473, y=-3.988762781111524, theta=0.048610563918094145
# Closest map is map_0001_1771970261302923084.png has a delta of 0.462303845 seconds
# Closest scan has a delta of 0.017230983 seconds
# mean_error: 0.1209929740080614 after 7 iterations
# Odometry pose in world: x=-0.2591936573078171, y=-3.9877249796823184, theta=-0.0946640237327975
# ICP pose in world: x=-0.12007103489205406, y=-3.988762781111524, theta=0.04861056391809416
# Closest map is map_0001_1771970261302923084.png has a delta of 0.413473208 seconds
# Closest scan has a delta of -0.031599654 seconds
# mean_error: 0.12099297400805953 after 7 iterations
# Odometry pose in world: x=-0.2591674359516258, y=-3.9877274693541214, theta=-0.094664887412254
# ICP pose in world: x=-0.12007103489205578, y=-3.9887627811115243, theta=0.04861056391809419
# Closest map is map_0001_1771970261302923084.png has a delta of 0.334396707 seconds
# Closest scan has a delta of 0.078967683 seconds
# mean_error: 0.12099169854850848 after 7 iterations
# Odometry pose in world: x=-0.2591994515668635, y=-3.9877244294890573, theta=-0.094666408733046
# ICP pose in world: x=-0.120078998747503, y=-3.9887669565930586, theta=0.04860986901653374
# Closest map is map_0001_1771970261302923084.png has a delta of 0.255400219 seconds
# Closest scan has a delta of -2.8805e-05 seconds
# mean_error: 0.12099169854850918 after 7 iterations
# Odometry pose in world: x=-0.2591732303359776, y=-3.987726919211957, theta=-0.094667264334184
# ICP pose in world: x=-0.12007899874750222, y=-3.98876695659306, theta=0.048609869016533025
# Closest map is map_0001_1771970261302923084.png has a delta of 0.059565013 seconds
# Closest scan has a delta of 0.126478198 seconds
# mean_error: 0.12099053415792634 after 7 iterations
# Odometry pose in world: x=-0.2592052458398065, y=-3.987723879280811, theta=-0.0946687779408947
# ICP pose in world: x=-0.120100217609942, y=-3.9887783559623853, theta=0.04860812558960352
# Closest map is map_0001_1771970261302923084.png has a delta of -0.020981932 seconds
# Closest scan has a delta of 0.045931253 seconds
# mean_error: 0.12099053415792585 after 7 iterations
# Odometry pose in world: x=-0.2591790247279846, y=-3.987726369054985, theta=-0.09466962570436652
# ICP pose in world: x=-0.12010021760994238, y=-3.988778355962387, theta=0.048608125589603826
# Closest map is map_0001_1771970261302923084.png has a delta of -0.063578507 seconds
# Closest scan has a delta of 0.003334678 seconds
# mean_error: 0.12099053415792635 after 7 iterations
# Odometry pose in world: x=-0.2592110401235037, y=-3.987723329057963, theta=-0.0946711318223183
# ICP pose in world: x=-0.12010021760994188, y=-3.988778355962387, theta=0.048608125589603576
# Closest map is map_0001_1771970261302923084.png has a delta of -0.136646958 seconds
# Closest scan has a delta of -0.069733773 seconds
# mean_error: 0.12099053415792625 after 7 iterations
# Odometry pose in world: x=-0.2591848191200427, y=-3.987725818884025, theta=-0.0946719719773441
# ICP pose in world: x=-0.12010021760994183, y=-3.9887783559623853, theta=0.04860812558960362
# Closest map is map_0001_1771970261302923084.png has a delta of -0.19967167 seconds
# Closest scan has a delta of 0.132525145 seconds
# mean_error: 0.12098894399250539 after 7 iterations
# Odometry pose in world: x=-0.2592168344082299, y=-3.987722778821516, theta=-0.0946734708208882
# ICP pose in world: x=-0.12009605364651255, y=-3.988775986378578, theta=0.04860837934010849
# Closest map is map_0001_1771970261302923084.png has a delta of -0.363861397 seconds
# Closest scan has a delta of -0.031664582 seconds
# mean_error: 0.1209889439925056 after 7 iterations
# Odometry pose in world: x=-0.2591906135052741, y=-3.9877252686998204, theta=-0.0946743035857843
# ICP pose in world: x=-0.1200960536465121, y=-3.9887759863785788, theta=0.048608379340108775
# Closest map is map_0001_1771970261302923084.png has a delta of -0.458520786 seconds
# Closest scan has a delta of 0.088014338 seconds
# mean_error: 0.12098766633149412 after 7 iterations
# Odometry pose in world: x=-0.2592226286880559, y=-3.9877222285721152, theta=-0.0946757953592485
# ICP pose in world: x=-0.12010388474031225, y=-3.988780102767278, theta=0.048607696478881336
# Closest map is map_0001_1771970261302923084.png has a delta of -0.522011978 seconds
# Closest scan has a delta of 0.024523146 seconds
# mean_error: 0.1209876663314947 after 7 iterations
# Odometry pose in world: x=-0.2591964078771234, y=-3.9877247185030873, theta=-0.0946766209420009
# ICP pose in world: x=-0.12010388474031092, y=-3.98878010276728, theta=0.048607696478881156
# Closest map is map_0001_1771970261302923084.png has a delta of -0.574973648 seconds
# Closest scan has a delta of -0.028438524 seconds
# mean_error: 0.12098766633149403 after 7 iterations
# Odometry pose in world: x=-0.2592284229559319, y=-3.9877216783105096, theta=-0.09467810584000089
# ICP pose in world: x=-0.1201038847403117, y=-3.9887801027672807, theta=0.048607696478880476
# Closest map is map_0001_1771970261302923084.png has a delta of -0.662674729 seconds
# Closest scan has a delta of 0.07085262 seconds
# mean_error: 0.12098638773046956 after 7 iterations
# Odometry pose in world: x=-0.2592022022295035, y=-3.9877241682944935, theta=-0.0946789244387396
# ICP pose in world: x=-0.12011228690303966, y=-3.9887845202998125, theta=0.048606964317410406
# Closest map is map_0002_1771970262676835950.png has a delta of 0.647019125 seconds
# Closest scan has a delta of 0.006633608 seconds
# mean_error: 0.11788659981558959 after 8 iterations
# Odometry pose in world: x=-0.2592342172059511, y=-3.9877211280373315, theta=-0.0946804026467534
# ICP pose in world: x=-0.0907149295428864, y=-3.9513337901956493, theta=0.05175645512341352
# Closest map is map_0002_1771970262676835950.png has a delta of 0.526951297 seconds
# Closest scan has a delta of -0.11343422 seconds
# mean_error: 0.11788659981559023 after 8 iterations
# Odometry pose in world: x=-0.2592079965566871, y=-3.9877236180746647, theta=-0.0946812144502666
# ICP pose in world: x=-0.09071492954288624, y=-3.95133379019565, theta=0.05175645512341338
# Closest map is map_0002_1771970262676835950.png has a delta of 0.490036746 seconds
# Closest scan has a delta of 0.101174542 seconds
# mean_error: 0.11788864464584262 after 8 iterations
# Odometry pose in world: x=-0.2592400114322455, y=-3.987720577753212, theta=-0.0946826861450046
# ICP pose in world: x=-0.09073656658743245, y=-3.951345453485486, theta=0.05175466577587835
# Closest map is map_0002_1771970262676835950.png has a delta of 0.430575811 seconds
# Closest scan has a delta of 0.041713607 seconds
# mean_error: 0.11788864464584367 after 8 iterations
# Odometry pose in world: x=-0.2592137908533172, y=-3.9877230678441924, theta=-0.0946834913331856
# ICP pose in world: x=-0.09073656658743118, y=-3.9513454534854864, theta=0.05175466577587764
# Closest map is map_0002_1771970262676835950.png has a delta of 0.350885008 seconds
# Closest scan has a delta of -0.037977196 seconds
# mean_error: 0.11788864464584324 after 8 iterations
# Odometry pose in world: x=-0.2592458056294687, y=-3.987720027458731, theta=-0.0946849566830904
# ICP pose in world: x=-0.09073656658743123, y=-3.9513454534854855, theta=0.0517546657758778
# Closest map is map_0002_1771970262676835950.png has a delta of 0.265419514 seconds
# Closest scan has a delta of -0.12344269 seconds
# mean_error: 0.11788864464584316 after 8 iterations
# Odometry pose in world: x=-0.2592195851143685, y=-3.987722517603637, theta=-0.094685755427392
# ICP pose in world: x=-0.09073656658743257, y=-3.951345453485487, theta=0.05175466577587808
# Closest map is map_0002_1771970262676835950.png has a delta of 0.196166139 seconds
# Closest scan has a delta of 0.073141507 seconds
# mean_error: 0.3786376389649645 after 3 iterations
# Odometry pose in world: x=-0.2501734946150298, y=-3.9885978090395935, theta=-0.098231857376799
# ICP pose in world: x=-0.07948693176334452, y=-3.910049339991495, theta=-0.036627650569630084
# Closest map is map_0002_1771970262676835950.png has a delta of 0.048919393 seconds
# Closest scan has a delta of -0.074105239 seconds
# mean_error: 0.37864659550868707 after 3 iterations
# Odometry pose in world: x=-0.2365926637096082, y=-3.9899574235666933, theta=-0.1013287412898543
# ICP pose in world: x=-0.07742822766781807, y=-3.9099658233321635, theta=-0.03666443932379715
# Closest map is map_0002_1771970262676835950.png has a delta of -0.137393298 seconds
# Closest scan has a delta of 0.105800976 seconds
# mean_error: 0.3846392565358529 after 4 iterations
# Odometry pose in world: x=-0.2216013850475867, y=-3.9914978446146905, theta=-0.1034614794955362
# ICP pose in world: x=-0.0026014117827697497, y=-3.8978423246364917, theta=-0.0384552333477655
# Closest map is map_0002_1771970262676835950.png has a delta of -0.229244265 seconds
# Closest scan has a delta of 0.013950009 seconds
# mean_error: 0.3845875434792462 after 4 iterations
# Odometry pose in world: x=-0.2063453733198793, y=-3.9930950720318727, theta=-0.1051683738417381
# ICP pose in world: x=-0.0011339029053134553, y=-3.897565138541345, theta=-0.03835987192565571
# Closest map is map_0002_1771970262676835950.png has a delta of -0.291754718 seconds
# Closest scan has a delta of -0.048560444 seconds
# mean_error: 0.38356498015639107 after 4 iterations
# Odometry pose in world: x=-0.1904935458667908, y=-3.994779776967716, theta=-0.1065932831267283
# ICP pose in world: x=0.0021270782679551348, y=-3.8973379333632145, theta=-0.038215526257974086
# Closest map is map_0002_1771970262676835950.png has a delta of -0.341740658 seconds
# Closest scan has a delta of 0.065005574 seconds
# mean_error: 0.11793929487402523 after 7 iterations
# Odometry pose in world: x=-0.1713117237276573, y=-3.996833507128555, theta=-0.1067270387134044
# ICP pose in world: x=-0.006363985537376826, y=-3.94359846669987, theta=0.03547847878313851
# Closest map is map_0002_1771970262676835950.png has a delta of -0.404705716 seconds
# Closest scan has a delta of 0.002040516 seconds
# mean_error: 0.11786315912015828 after 7 iterations
# Odometry pose in world: x=-0.1527335353777767, y=-3.9988198584832677, theta=-0.10630060236877252
# ICP pose in world: x=-0.003983675013634391, y=-3.9438726952945653, theta=0.03549953728392201
# Closest map is map_0002_1771970262676835950.png has a delta of -0.448099404 seconds
# Closest scan has a delta of -0.041353172 seconds
# mean_error: 0.11761840153140382 after 7 iterations
# Odometry pose in world: x=-0.134525321595784, y=-4.000760120129801, theta=-0.106017577931107
# ICP pose in world: x=0.00013410301069727293, y=-3.945818543830311, theta=0.03530118109692905
# Closest map is map_0002_1771970262676835950.png has a delta of -0.531558828 seconds
# Closest scan has a delta of 0.089232635 seconds
# mean_error: 0.11888022669183324 after 8 iterations
# Odometry pose in world: x=-0.1165479518396996, y=-4.002671989187987, theta=-0.1058832546283424
# ICP pose in world: x=0.06858724751785539, y=-3.9406844369106824, theta=0.039305563066235
# Closest map is map_0002_1771970262676835950.png has a delta of -0.615757031 seconds
# Closest scan has a delta of 0.005034432 seconds
# mean_error: 0.11902495883668725 after 8 iterations
# Odometry pose in world: x=-0.0985793496328911, y=-4.00458113608007, theta=-0.1058205952382407
# ICP pose in world: x=0.06876122883841634, y=-3.9410728134692374, theta=0.03984725480679408
# Closest map is map_0002_1771970262676835950.png has a delta of -0.725155098 seconds
# Closest scan has a delta of -0.104363635 seconds
# mean_error: 0.11856597541775224 after 7 iterations
# Odometry pose in world: x=-0.0806962704366571, y=-4.00648035247197, theta=-0.105789943290716
# ICP pose in world: x=0.06050891864418184, y=-3.937412039136764, theta=0.03644807266254631
# Closest map is map_0002_1771970262676835950.png has a delta of -0.807667522 seconds
# Closest scan has a delta of 0.088643272 seconds
# mean_error: 0.1199930226233415 after 8 iterations
# Odometry pose in world: x=-0.0627657314614416, y=-4.008384159761955, theta=-0.1057710253064315
# ICP pose in world: x=0.1069945337204592, y=-3.9348082083853564, theta=0.038830741317762846
# Closest map is map_0003_1771970264338306300.png has a delta of 0.781461279 seconds
# Closest scan has a delta of 0.016301723 seconds
# mean_error: 0.11399686402395781 after 8 iterations
# Odometry pose in world: x=-0.0448976595423783, y=-4.010281047515598, theta=-0.1057581787838933
# ICP pose in world: x=0.16897015065954524, y=-3.906107298051775, theta=0.041405599943715926
# Closest map is map_0003_1771970264338306300.png has a delta of 0.719247701 seconds
# Closest scan has a delta of -0.045911855 seconds
# mean_error: 0.11399154187555924 after 8 iterations
# Odometry pose in world: x=-0.0269730758505653, y=-4.012183711349907, theta=-0.105746392835679
# ICP pose in world: x=0.1693229053977875, y=-3.9060655336568657, theta=0.04144978910129474
# Closest map is map_0003_1771970264338306300.png has a delta of 0.645626817 seconds
# Closest scan has a delta of 0.065124685 seconds
# mean_error: 0.11431834414198025 after 7 iterations
# Odometry pose in world: x=-0.0091073186389714, y=-4.014079934790467, theta=-0.10573647475900139
# ICP pose in world: x=0.20809814568415524, y=-3.8934652525605777, theta=0.03884054181740382
# Closest map is map_0003_1771970264338306300.png has a delta of 0.569973518 seconds
# Closest scan has a delta of -0.010528614 seconds
# mean_error: 0.11430672976952876 after 7 iterations
# Odometry pose in world: x=0.0088163165678835, y=-4.015982115079246, theta=-0.1057258509342944
# ICP pose in world: x=0.2162008126415702, y=-3.8997523111634256, theta=0.03911412511690031
# Closest map is map_0003_1771970264338306300.png has a delta of 0.509796656 seconds
# Closest scan has a delta of -0.070705476 seconds
# mean_error: 0.11418542808172952 after 7 iterations
# Odometry pose in world: x=0.0266817168054486, y=-4.017877932656438, theta=-0.10571628130823331
# ICP pose in world: x=0.21887641853086542, y=-3.9015773357752868, theta=0.03899689918406576
# Closest map is map_0003_1771970264338306300.png has a delta of -0.069259238 seconds
# Closest scan has a delta of 0.067770522 seconds
# mean_error: 0.11593765088624673 after 8 iterations
# Odometry pose in world: x=0.044605251099337, y=-4.019779737986839, theta=-0.1057058522096908
# ICP pose in world: x=0.26005889255633324, y=-3.900149128650328, theta=0.040756279485739864
# Closest map is map_0003_1771970264338306300.png has a delta of -0.137076464 seconds
# Closest scan has a delta of -4.6704e-05 seconds
# mean_error: 0.11587713716764034 after 8 iterations
# Odometry pose in world: x=0.0624706269750197, y=-4.021675192696108, theta=-0.1056963959873759
# ICP pose in world: x=0.2617037188865881, y=-3.900254141160438, theta=0.04009537863209714
# Closest map is map_0003_1771970264338306300.png has a delta of -0.206730534 seconds
# Closest scan has a delta of -0.069700774 seconds
# mean_error: 0.11607258720846544 after 8 iterations
# Odometry pose in world: x=0.0803941711391704, y=-4.023576638810182, theta=-0.1056859849675651
# ICP pose in world: x=0.26393499227128464, y=-3.9025468718829974, theta=0.04123468922279525
# Closest map is map_0003_1771970264338306300.png has a delta of -0.291173565 seconds
# Closest scan has a delta of 0.061347818 seconds
# mean_error: 0.11548747767588874 after 9 iterations
# Odometry pose in world: x=0.0982595732092016, y=-4.025471737451998, theta=-0.10567653808382259
# ICP pose in world: x=0.3130803236523044, y=-3.8903433077162535, theta=0.042409654783196776
# Closest map is map_0003_1771970264338306300.png has a delta of -0.390232144 seconds
# Closest scan has a delta of -0.037710761 seconds
# mean_error: 0.11524415357871046 after 8 iterations
# Odometry pose in world: x=0.116183153724806, y=-4.027372827520874, theta=-0.10566613016322819
# ICP pose in world: x=0.31007947587033574, y=-3.8904205635383677, theta=0.04071133984920812
# Closest map is map_0003_1771970264338306300.png has a delta of -0.453510213 seconds
# Closest scan has a delta of 0.066862651 seconds
# mean_error: 0.11567156597555868 after 8 iterations
# Odometry pose in world: x=0.1340485930428749, y=-4.029267571412481, theta=-0.1056566837299999
# ICP pose in world: x=0.3600615741525072, y=-3.88915980619308, theta=0.039227840470725306
# Closest map is map_0003_1771970264338306300.png has a delta of -0.508142504 seconds
# Closest scan has a delta of 0.01223036 seconds
# mean_error: 0.1157538371075899 after 8 iterations
# Odometry pose in world: x=0.1519722093599685, y=-4.0311683054096985, theta=-0.1056462753182238
# ICP pose in world: x=0.3625067069370289, y=-3.8899104559018665, theta=0.039335002193521575
# Closest map is map_0003_1771970264338306300.png has a delta of -0.556061667 seconds
# Closest scan has a delta of -0.035688803 seconds
# mean_error: 0.11575383710758946 after 8 iterations
# Odometry pose in world: x=0.1698376856037894, y=-4.033062694505352, theta=-0.1056368281123115
# ICP pose in world: x=0.36250670693702797, y=-3.889910455901864, theta=0.039335002193522
# Closest map is map_0003_1771970264338306300.png has a delta of -0.601280318 seconds
# Closest scan has a delta of 0.067795485 seconds
# mean_error: 0.11554897629494006 after 8 iterations
# Odometry pose in world: x=0.1877613399472031, y=-4.034963072639133, theta=-0.1056264186826257
# ICP pose in world: x=0.40400876286758214, y=-3.885119773742294, theta=0.03809913563548293
# Closest map is map_0003_1771970264338306300.png has a delta of -0.658096079 seconds
# Closest scan has a delta of 0.010979724 seconds
# mean_error: 0.11575654607921469 after 9 iterations
# Odometry pose in world: x=0.2056268540162105, y=-4.036857106998667, theta=-0.10561697038364011
# ICP pose in world: x=0.4115763236273056, y=-3.888420755473058, theta=0.03975458767625873
# Closest map is map_0003_1771970264338306300.png has a delta of -0.735416634 seconds
# Closest scan has a delta of -0.066340831 seconds
# mean_error: 0.11575654607921404 after 9 iterations
# Odometry pose in world: x=0.2235505456295202, y=-4.0387571291492925, theta=-0.1056065597801777
# ICP pose in world: x=0.4115763236273055, y=-3.888420755473059, theta=0.03975458767625866
# Closest map is map_0003_1771970264338306300.png has a delta of -0.776123561 seconds
# Closest scan has a delta of 0.044643844 seconds
# mean_error: 0.11850910519675223 after 8 iterations
# Odometry pose in world: x=0.2414160971585811, y=-4.04065080869183, theta=-0.1055971102173117
# ICP pose in world: x=0.4642245251140613, y=-3.8925365876505156, theta=0.039821256947248966
# Closest map is map_0003_1771970264338306300.png has a delta of -0.820801806 seconds
# Closest scan has a delta of -3.4401e-05 seconds
# mean_error: 0.1179266370923913 after 7 iterations
# Odometry pose in world: x=0.2593398263146458, y=-4.042550474838828, theta=-0.1055866978718986
# ICP pose in world: x=0.45301779708548523, y=-3.889740861619999, theta=0.03698984782541901
# Closest map is map_0003_1771970264338306300.png has a delta of -0.881059804 seconds
# Closest scan has a delta of -0.060292399 seconds
# mean_error: 0.11796501817945482 after 7 iterations
# Odometry pose in world: x=0.2772054149314067, y=-4.044443799444825, theta=-0.1055772442376776
# ICP pose in world: x=0.45467900860684884, y=-3.8889741191508493, theta=0.03717098667979922
# Closest map is map_0003_1771970264338306300.png has a delta of -0.922985899 seconds
# Closest scan has a delta of 0.052695083 seconds
# mean_error: 0.11929091534430135 after 7 iterations
# Odometry pose in world: x=0.2951291922886834, y=-4.046343111185997, theta=-0.1055668934444386
# ICP pose in world: x=0.4914741265339506, y=-3.882796515937639, theta=0.03791512846286345
# Closest map is map_0003_1771970264338306300.png has a delta of -0.976990854 seconds
# Closest scan has a delta of -0.001309872 seconds
# mean_error: 0.11928165898732654 after 7 iterations
# Odometry pose in world: x=0.3129948105008686, y=-4.0482360807470945, theta=-0.1055573966268463
# ICP pose in world: x=0.494526267211959, y=-3.8845039909402357, theta=0.037661531263986706
# Closest map is map_0003_1771970264338306300.png has a delta of -1.061682289 seconds
# Closest scan has a delta of -0.086001307 seconds
# mean_error: 0.1192379829132283 after 8 iterations
# Odometry pose in world: x=0.3309186249603888, y=-4.050135035550956, theta=-0.1055469211339357
# ICP pose in world: x=0.5102937495340529, y=-3.888412179028814, theta=0.03990916058875632
# Closest map is map_0003_1771970264338306300.png has a delta of -1.12694046 seconds
# Closest scan has a delta of 0.043435077 seconds
# mean_error: 0.12098752609884908 after 8 iterations
# Odometry pose in world: x=0.3487842803673519, y=-4.052027649097697, theta=-0.1055375204384551
# ICP pose in world: x=0.5639960984708774, y=-3.8766757517919372, theta=0.04156991793651039
# Closest map is map_0003_1771970264338306300.png has a delta of -1.184741523 seconds
# Closest scan has a delta of -0.014365986 seconds
# mean_error: 0.12093938356406547 after 8 iterations
# Odometry pose in world: x=0.3667081221224669, y=-4.053926247103614, theta=-0.10552710739626091
# ICP pose in world: x=0.5653097264399055, y=-3.876754124482243, theta=0.04150316219867019
# Closest map is map_0003_1771970264338306300.png has a delta of -1.226411204 seconds
# Closest scan has a delta of -0.056035667 seconds
# mean_error: 0.12093938356406488 after 8 iterations
# Odometry pose in world: x=0.3845738241862063, y=-4.0558185071676345, theta=-0.1055176549626249
# ICP pose in world: x=0.5653097264399052, y=-3.8767541244822428, theta=0.04150316219867063
# Closest map is map_0003_1771970264338306300.png has a delta of -1.31442322 seconds
# Closest scan has a delta of 0.044391629 seconds
# mean_error: 0.11850653683941505 after 7 iterations
# Odometry pose in world: x=0.4024977038391011, y=-4.057716749109453, theta=-0.1055072399736749
# ICP pose in world: x=0.5989350786803196, y=-3.8807375517839464, theta=0.03649166058352502
# Closest map is map_0003_1771970264338306300.png has a delta of -1.486721549 seconds
# Closest scan has a delta of 0.102555813 seconds
# mean_error: 0.12012033867259927 after 7 iterations
# Odometry pose in world: x=0.4203634436275916, y=-4.059608654231933, theta=-0.1054977864568961
# ICP pose in world: x=0.6462273865231993, y=-3.8800109709439137, theta=0.03777148220538168
# Closest map is map_0003_1771970264338306300.png has a delta of -1.535491618 seconds
# Closest scan has a delta of 0.053785744 seconds
# mean_error: 0.12012033867259884 after 7 iterations
# Odometry pose in world: x=0.4382873609316689, y=-4.061506540037817, theta=-0.10548737053942751
# ICP pose in world: x=0.6462273865231984, y=-3.880010970943914, theta=0.03777148220538211
# Closest map is map_0003_1771970264338306300.png has a delta of -1.573146479 seconds
# Closest scan has a delta of 0.016130883 seconds
# mean_error: 0.12017304574567789 after 7 iterations
# Odometry pose in world: x=0.4561531383668588, y=-4.063398090176622, theta=-0.1054779161794396
# ICP pose in world: x=0.647409605125039, y=-3.8788313259158835, theta=0.03782261509657128
# Closest map is map_0003_1771970264338306300.png has a delta of -1.642637882 seconds
# Closest scan has a delta of -0.05336052 seconds
# mean_error: 0.1202148028951454 after 7 iterations
# Odometry pose in world: x=0.4740770932988869, y=-4.065295619812908, theta=-0.1054674994223641
# ICP pose in world: x=0.6498069952655346, y=-3.8789496725194885, theta=0.03795005907854914
# Closest map is map_0003_1771970264338306300.png has a delta of -1.68841955 seconds
# Closest scan has a delta of 0.071299317 seconds
# mean_error: 0.11961425702878292 after 8 iterations
# Odometry pose in world: x=0.4919429083616475, y=-4.067186814935643, theta=-0.1054580442632237
# ICP pose in world: x=0.6891424956897316, y=-3.8691697983449322, theta=0.037392843001301995
# Closest map is map_0003_1771970264338306300.png has a delta of -1.751093175 seconds
# Closest scan has a delta of 0.008625692 seconds
# mean_error: 0.11962382603584566 after 8 iterations
# Odometry pose in world: x=0.5098669009105752, y=-4.069083988371472, theta=-0.10544762668919182
# ICP pose in world: x=0.6896416595676058, y=-3.8692184561078222, theta=0.037352533335456385
# Closest map is map_0003_1771970264338306300.png has a delta of -1.806587956 seconds
# Closest scan has a delta of -0.046869089 seconds
# mean_error: 0.11959819839329723 after 8 iterations
# Odometry pose in world: x=0.527732753584391, y=-4.070974828447588, theta=-0.105438170732497
# ICP pose in world: x=0.6940451302064096, y=-3.8720974006526796, theta=0.03794848634204597
# Closest map is map_0003_1771970264338306300.png has a delta of -1.842062358 seconds
# Closest scan has a delta of 0.073059877 seconds
# mean_error: 0.12096241244275349 after 7 iterations
# Odometry pose in world: x=0.5456567837369982, y=-4.072871645652065, theta=-0.1054277523105186
# ICP pose in world: x=0.7355379619601284, y=-3.866244147426182, theta=0.03478604297867958
# Closest map is map_0003_1771970264338306300.png has a delta of -1.898007254 seconds
# Closest scan has a delta of 0.017114981 seconds
# mean_error: 0.12068890578947383 after 7 iterations
# Odometry pose in world: x=0.5635226739842145, y=-4.074762130646483, theta=-0.1054182954291009
# ICP pose in world: x=0.7437360289166206, y=-3.869165468002939, theta=0.03531288340872934
# Closest map is map_0003_1771970264338306300.png has a delta of -1.977772258 seconds
# Closest scan has a delta of -0.062650023 seconds
# mean_error: 0.12070769210819397 after 8 iterations
# Odometry pose in world: x=0.5814467416384058, y=-4.076658591572346, theta=-0.1054078756625609
# ICP pose in world: x=0.750392803825878, y=-3.872974152070004, theta=0.03794442815878765
# Closest map is map_0003_1771970264338306300.png has a delta of -2.029120699 seconds
# Closest scan has a delta of 0.042015324 seconds
# mean_error: 0.12213879739260403 after 8 iterations
# Odometry pose in world: x=0.5993126685268969, y=-4.078548721298652, theta=-0.105398412683654
# ICP pose in world: x=0.7940368131939177, y=-3.8756848272974564, theta=0.035273085110173866
# Closest map is map_0003_1771970264338306300.png has a delta of -2.087357373 seconds
# Closest scan has a delta of -0.01622135 seconds
# mean_error: 0.12178071565671429 after 8 iterations
# Odometry pose in world: x=0.6172367759638063, y=-4.080444826176464, theta=-0.1053880052710176
# ICP pose in world: x=0.7992610925716683, y=-3.8787551255510073, theta=0.03502733376430286
# Closest map is map_0003_1771970264338306300.png has a delta of -2.136152427 seconds
# Closest scan has a delta of -0.065016404 seconds
# mean_error: 0.12186984405487471 after 8 iterations
# Odometry pose in world: x=0.6351027406181439, y=-4.082334600968597, theta=-0.105378547478149
# ICP pose in world: x=0.8022648472652606, y=-3.8785268605679675, theta=0.03521297335216262
# Closest map is map_0003_1771970264338306300.png has a delta of -2.22564356 seconds
# Closest scan has a delta of 0.027589635 seconds
# mean_error: 0.12355382130788624 after 7 iterations
# Odometry pose in world: x=0.6530268846207254, y=-4.084230349486011, theta=-0.10536812043226859
# ICP pose in world: x=0.8395266176994397, y=-3.871268254454487, theta=0.036619567852468185
# Closest map is map_0003_1771970264338306300.png has a delta of -2.293334054 seconds
# Closest scan has a delta of -0.040100859 seconds
# mean_error: 0.12368833619815074 after 7 iterations
# Odometry pose in world: x=0.659185141535283, y=-4.084786768509913, theta=-0.0748491893594482
# ICP pose in world: x=0.8401875668569065, y=-3.868919339013667, theta=0.03886735499279039
# Closest map is map_0003_1771970264338306300.png has a delta of -2.386180102 seconds
# Closest scan has a delta of 0.08202128 seconds
# mean_error: 0.12231694513845004 after 9 iterations
# Odometry pose in world: x=0.6639264259431625, y=-4.085066456932473, theta=-0.0429942691970777
# ICP pose in world: x=0.8668311884290337, y=-3.8710026246495883, theta=0.09256475759089793
# Closest map is map_0003_1771970264338306300.png has a delta of -2.432697078 seconds
# Closest scan has a delta of 0.035504304 seconds
# mean_error: 0.12232723859737143 after 8 iterations
# Odometry pose in world: x=0.6677364441012775, y=-4.085166705182327, theta=-0.0096170943555373
# ICP pose in world: x=0.8641217639799446, y=-3.8698537384049745, theta=0.0919418139517512
# Closest map is map_0003_1771970264338306300.png has a delta of -2.481552034 seconds
# Closest scan has a delta of -0.013350652 seconds
# mean_error: 0.12182499446068876 after 7 iterations
# Odometry pose in world: x=0.6696660829171912, y=-4.085150859215043, theta=0.0260404902545037
# ICP pose in world: x=0.8625965002677641, y=-3.873325500035728, theta=0.0916045597951931
# Closest map is map_0003_1771970264338306300.png has a delta of -2.532737369 seconds
# Closest scan has a delta of 0.054224138 seconds
# mean_error: 0.12268267253896364 after 7 iterations
# Odometry pose in world: x=0.6705102780459863, y=-4.0851134543176935, theta=0.0625182960372171
# ICP pose in world: x=0.8562871859225838, y=-3.870381795354116, theta=0.18084334222891216
# Closest map is map_0003_1771970264338306300.png has a delta of -2.577385383 seconds
# Closest scan has a delta of 0.009576124 seconds
# mean_error: 0.12234717944595183 after 6 iterations
# Odometry pose in world: x=0.6708222642650628, y=-4.085088232246259, theta=0.09881792065394332
# ICP pose in world: x=0.8491648365432128, y=-3.878119945258978, theta=0.17829415215723668
# Closest map is map_0003_1771970264338306300.png has a delta of -2.637537722 seconds
# Closest scan has a delta of -0.050576215 seconds
# mean_error: 0.12190823138038398 after 4 iterations
# Odometry pose in world: x=0.671012696209863, y=-4.08506587087769, theta=0.1349604402279864
# ICP pose in world: x=0.8224614448725417, y=-3.896096858578919, theta=0.1744211381527195
# Closest map is map_0003_1771970264338306300.png has a delta of -2.685157313 seconds
# Closest scan has a delta of 0.051357605 seconds
# mean_error: 0.12180874612800903 after 7 iterations
# Odometry pose in world: x=0.6710719368548238, y=-4.085056736053127, theta=0.1710267758406707
# ICP pose in world: x=0.8543469501884565, y=-3.8690007618480005, theta=0.2723443834444805
# Closest map is map_0003_1771970264338306300.png has a delta of -2.739317962 seconds
# Closest scan has a delta of -0.002803044 seconds
# mean_error: 0.1209861668345306 after 5 iterations
# Odometry pose in world: x=0.6711608203422819, y=-4.085039730098846, theta=0.20706113146144461
# ICP pose in world: x=0.8387448095030035, y=-3.8835056494939293, theta=0.26890762333842844
# Closest map is map_0003_1771970264338306300.png has a delta of -2.798508489 seconds
# Closest scan has a delta of -0.061993571 seconds
# mean_error: 0.12117538017664511 after 4 iterations
# Odometry pose in world: x=0.6711801019952732, y=-4.085035315555207, theta=0.24308160163015494
# ICP pose in world: x=0.84277645830841, y=-3.8933051492374187, theta=0.2718408796212721
# Closest map is map_0003_1771970264338306300.png has a delta of -2.85152572 seconds
# Closest scan has a delta of 0.036223667 seconds
# mean_error: 0.12400870022606211 after 6 iterations
# Odometry pose in world: x=0.6712513104970036, y=-4.085016289412941, theta=0.279098730492465
# ICP pose in world: x=0.8518996170523071, y=-3.8697760517704523, theta=0.36471609020518747
# Closest map is map_0003_1771970264338306300.png has a delta of -2.903056727 seconds
# Closest scan has a delta of -0.01530734 seconds
# mean_error: 0.12331403830045257 after 4 iterations
# Odometry pose in world: x=0.6712640182686214, y=-4.085012398719529, theta=0.3151101677214383
# ICP pose in world: x=0.8265306455711926, y=-3.8884056013005837, theta=0.3604306226983965
# Closest map is map_0003_1771970264338306300.png has a delta of -2.976387776 seconds
# Closest scan has a delta of 0.04846996 seconds
# mean_error: 0.12343666661233026 after 6 iterations
# Odometry pose in world: x=0.6713313390230767, y=-4.08498910505254, theta=0.3511218522526388
# ICP pose in world: x=0.8510661389803609, y=-3.866679956707462, theta=0.4529025374258839
# Closest map is map_0003_1771970264338306300.png has a delta of -3.00405451 seconds
# Closest scan has a delta of 0.020803226 seconds
# mean_error: 0.123096829671673 after 5 iterations
# Odometry pose in world: x=0.6713423761474795, y=-4.084984835236492, theta=0.3871326635523769
# ICP pose in world: x=0.845859553578589, y=-3.87246581062927, theta=0.4517892206891746
# Closest map is map_0003_1771970264338306300.png has a delta of -3.054522101 seconds
# Closest scan has a delta of -0.029664365 seconds
# mean_error: 0.12346323201173981 after 4 iterations
# Odometry pose in world: x=0.6714072009614976, y=-4.084957034278201, theta=0.423143357819236
# ICP pose in world: x=0.8453535148031742, y=-3.8915595867354495, theta=0.4548091487878088
# Closest map is map_0003_1771970264338306300.png has a delta of -3.115266553 seconds
# Closest scan has a delta of -0.090408817 seconds
# mean_error: 0.12743037218523062 after 6 iterations
# Odometry pose in world: x=0.671417511973014, y=-4.084952165581274, theta=0.4591534553120699
# ICP pose in world: x=0.8798421235822509, y=-3.873544769717185, theta=0.46584752789744843
# Closest map is map_0003_1771970264338306300.png has a delta of -3.254729238 seconds
# Closest scan has a delta of 0.019721509 seconds
# mean_error: 0.12268907322956418 after 4 iterations
# Odometry pose in world: x=0.6714798798038712, y=-4.084919921130932, theta=0.495163539332522
# ICP pose in world: x=0.8396091776315652, y=-3.8892658847654866, theta=0.5376946303932302
# Closest map is map_0003_1771970264338306300.png has a delta of -3.313970466 seconds
# Closest scan has a delta of -0.039519719 seconds
# mean_error: 0.1259074732488809 after 5 iterations
# Odometry pose in world: x=0.671489563814473, y=-4.08491446394152, theta=0.5311731193252147
# ICP pose in world: x=0.873069822216563, y=-3.881071085076262, theta=0.5484612538551765
# Closest map is map_0003_1771970264338306300.png has a delta of -3.413204621 seconds
# Closest scan has a delta of 0.040061928 seconds
# mean_error: 0.12086208518238196 after 6 iterations
# Odometry pose in world: x=0.6715492053779786, y=-4.084877964815135, theta=0.5671827052858627
# ICP pose in world: x=0.8646969273729193, y=-3.8789136235291064, theta=0.6309192807054296
# Closest map is map_0003_1771970264338306300.png has a delta of -3.451250317 seconds
# Closest scan has a delta of 0.002016232 seconds
# mean_error: 0.12033320209633103 after 3 iterations
# Odometry pose in world: x=0.6715582425541631, y=-4.0848719767127175, theta=0.6031918439645807
# ICP pose in world: x=0.8180714200452184, y=-3.906991626629642, theta=0.6269082396171235
# Closest map is map_0003_1771970264338306300.png has a delta of -3.508523115 seconds
# Closest scan has a delta of -0.055256566 seconds
# mean_error: 0.12343025263654131 after 18 iterations
# Odometry pose in world: x=0.6716148786747929, y=-4.084831441292492, theta=0.6392010018279082
# ICP pose in world: x=0.8935464375807616, y=-3.8803852255678413, theta=0.6397898106876039
# Closest map is map_0003_1771970264338306300.png has a delta of -3.56561461 seconds
# Closest scan has a delta of 0.086776659 seconds
# mean_error: 0.12094508519734581 after 3 iterations
# Odometry pose in world: x=0.6716232459847882, y=-4.084824984769287, theta=0.6752097628374468
# ICP pose in world: x=0.8107591627032387, y=-3.913104743610435, theta=0.7025248541054457
# Closest map is map_0003_1771970264338306300.png has a delta of -3.634837794 seconds
# Closest scan has a delta of 0.017553475 seconds
# mean_error: 0.12258237790638113 after 5 iterations
# Odometry pose in world: x=0.6717746468504239, y=-4.084701873994434, theta=0.6901994846121738
# ICP pose in world: x=0.8580401041920133, y=-3.88346248721677, theta=0.7129862109660073
# Closest map is map_0003_1771970264338306300.png has a delta of -3.691833798 seconds
# Closest scan has a delta of -0.039442529 seconds
# mean_error: 0.12449786366109779 after 7 iterations
# Odometry pose in world: x=0.6717509918520712, y=-4.084721877557437, theta=0.7137128749357107
# ICP pose in world: x=0.8812004040887813, y=-3.8743182805511585, theta=0.7181001941442674
# Closest map is map_0003_1771970264338306300.png has a delta of -3.766796377 seconds
# Closest scan has a delta of 0.023902794 seconds
# mean_error: 0.11984869374269953 after 5 iterations
# Odometry pose in world: x=0.6717470382021269, y=-4.08472542060002, theta=0.7476491920196119
# ICP pose in world: x=0.8535928307115844, y=-3.880956352227014, theta=0.7877619196315331
# Closest map is map_0003_1771970264338306300.png has a delta of -3.826688061 seconds
# Closest scan has a delta of -0.03598889 seconds
# mean_error: 0.12285720143383388 after 4 iterations
# Odometry pose in world: x=0.671726732369376, y=-4.084744933052237, theta=0.7833023465447575
# ICP pose in world: x=0.8467664068259786, y=-3.8902033216072285, theta=0.7954097998930636
# Closest map is map_0003_1771970264338306300.png has a delta of -3.870003149 seconds
# Closest scan has a delta of -0.079303978 seconds
# mean_error: 0.12364117027689993 after 16 iterations
# Odometry pose in world: x=0.6717626146847392, y=-4.08470789301596, theta=0.8192434681710549
# ICP pose in world: x=0.8914966826924782, y=-3.8797711566679505, theta=0.7993507961886552
# Closest map is map_0003_1771970264338306300.png has a delta of -3.922328634 seconds
# Closest scan has a delta of 0.046434287 seconds
# mean_error: 0.1212102650170443 after 3 iterations
# Odometry pose in world: x=0.6717645068411983, y=-4.08470579375203, theta=0.8552361991950376
# ICP pose in world: x=0.8185721493940497, y=-3.910873857182345, theta=0.8774055990692188
# Closest map is map_0003_1771970264338306300.png has a delta of -3.968802221 seconds
# Closest scan has a delta of -3.93e-05 seconds
# mean_error: 0.12462384752771664 after 14 iterations
# Odometry pose in world: x=0.6718069855486112, y=-4.08465511060217, theta=0.8912399691870443
# ICP pose in world: x=0.8895902439761669, y=-3.8731941328230604, theta=0.8910444612090813
# Closest map is map_0003_1771970264338306300.png has a delta of -4.013061409 seconds
# Closest scan has a delta of -0.044298488 seconds
# mean_error: 0.12489477042425652 after 17 iterations
# Odometry pose in world: x=0.671812273146207, y=-4.084648319412012, theta=0.927246367830534
# ICP pose in world: x=0.8911588327831022, y=-3.8707985370154594, theta=0.8914219744650961
# Closest map is map_0003_1771970264338306300.png has a delta of -4.22547495 seconds
# Closest scan has a delta of 0.052581985 seconds
# mean_error: 0.1332309636622025 after 11 iterations
# Odometry pose in world: x=0.6718519896141042, y=-4.084593334469265, theta=0.9632538097902303
# ICP pose in world: x=0.9190022370228191, y=-3.856707991533001, theta=0.9736835615007133
# Closest map is map_0003_1771970264338306300.png has a delta of -4.302859628 seconds
# Closest scan has a delta of -0.024802693 seconds
# mean_error: 0.13323096366220175 after 10 iterations
# Odometry pose in world: x=0.677111030469177, y=-4.076922726221164, theta=0.9763340703704656
# ICP pose in world: x=0.9190022370228199, y=-3.8567079915330025, theta=0.9736835615007139
# Closest map is map_0003_1771970264338306300.png has a delta of -4.36907461 seconds
# Closest scan has a delta of -0.091017675 seconds
# mean_error: 0.13323096366220197 after 12 iterations
# Odometry pose in world: x=0.6787768391744824, y=-4.074395285594036, theta=0.9997820415392854
# ICP pose in world: x=0.9190022370228192, y=-3.8567079915330016, theta=0.9736835615007139
# Closest map is map_0003_1771970264338306300.png has a delta of -4.469503882 seconds
# Closest scan has a delta of 0.048919086 seconds
# mean_error: 0.12724627178436201 after 8 iterations
# Odometry pose in world: x=0.6800991854537943, y=-4.072256972626211, theta=1.0341231236275248
# ICP pose in world: x=0.9016215160786877, y=-3.8656773287674513, theta=1.042276890506373
# Closest map is map_0003_1771970264338306300.png has a delta of -4.518449468 seconds
# Closest scan has a delta of -2.65e-05 seconds
# mean_error: 0.12794150397645873 after 21 iterations
# Odometry pose in world: x=0.6810867893532229, y=-4.070529331067332, theta=1.0688455792094391
# ICP pose in world: x=0.911613426511948, y=-3.8610877590167934, theta=1.0440877205375552
# Closest map is map_0003_1771970264338306300.png has a delta of -4.574404752 seconds
# Closest scan has a delta of -0.055981784 seconds
# mean_error: 0.12794150397645845 after 25 iterations
# Odometry pose in world: x=0.6814617002250849, y=-4.069815841067798, theta=1.105131077354832
# ICP pose in world: x=0.911613426511948, y=-3.861087759016792, theta=1.0440877205375552
# Closest map is map_0003_1771970264338306300.png has a delta of -4.61902734 seconds
# Closest scan has a delta of 0.071580057 seconds
# mean_error: 0.12790546875733944 after 13 iterations
# Odometry pose in world: x=0.6816290871850217, y=-4.069467132006071, theta=1.1413908125705066
# ICP pose in world: x=0.9100774468617394, y=-3.863351902724983, theta=1.130782049164959
# Closest map is map_0003_1771970264338306300.png has a delta of -4.732208505 seconds
# Closest scan has a delta of -0.041601108 seconds
# mean_error: 0.12777728746582956 after 20 iterations
# Odometry pose in world: x=0.6816828703101955, y=-4.069343839373505, theta=1.177525060340024
# ICP pose in world: x=0.9127072024301999, y=-3.8591318028925192, theta=1.1307632302467836
# Closest map is map_0003_1771970264338306300.png has a delta of -4.794468418 seconds
# Closest scan has a delta of 0.077046104 seconds
# mean_error: 0.12762498660124744 after 7 iterations
# Odometry pose in world: x=0.681726199422429, y=-4.069233840040065, theta=1.2135882528234727
# ICP pose in world: x=0.8909294058214348, y=-3.8592347626512526, theta=1.219225714979737
# Closest map is map_0003_1771970264338306300.png has a delta of -4.847909458 seconds
# Closest scan has a delta of 0.023605064 seconds
# mean_error: 0.12834243634466483 after 24 iterations
# Odometry pose in world: x=0.6817357025406182, y=-4.069206905960024, theta=1.24961909891528
# ICP pose in world: x=0.9029482821658552, y=-3.8507829700519993, theta=1.221113333988891
# Closest map is map_0003_1771970264338306300.png has a delta of -4.923711779 seconds
# Closest scan has a delta of -0.052197257 seconds
# mean_error: 0.12834243634466624 after 23 iterations
# Odometry pose in world: x=0.6817582038451077, y=-4.06913497342485, theta=1.2856367951719063
# ICP pose in world: x=0.9029482821658562, y=-3.8507829700520015, theta=1.2211133339888902
# Closest map is map_0003_1771970264338306300.png has a delta of -4.992909694 seconds
# Closest scan has a delta of 0.058700464 seconds
# mean_error: 0.12367333730314393 after 11 iterations
# ...
# Odometry pose in world: x=8.542446752900284, y=2.164270843639043, theta=2.3761610922141174
# ICP pose in world: x=8.754274484328084, y=1.8176231279656618, theta=2.2920220122747175
# Closest map is map_0012_1771970331425858800.png has a delta of -0.521483392 seconds
# Closest scan has a delta of 0.015431591 seconds
# mean_error: 0.7294856606935298 after 1 iterations
# Odometry pose in world: x=8.542470700304197, y=2.1642478337141426, theta=2.376151559839284
# ICP pose in world: x=8.754051579023583, y=1.8178970225956441, theta=2.292062559858598
# Closest map is map_0012_1771970331425858800.png has a delta of -0.568264726 seconds
# Closest scan has a delta of -0.031349743 seconds
# mean_error: 0.7294856606935298 after 1 iterations
# Odometry pose in world: x=8.542452466629856, y=2.164265353910741, theta=2.376142641558181
# ICP pose in world: x=8.754051579023585, y=1.8178970225956423, theta=2.2920625598585977
# Closest map is map_0012_1771970331425858800.png has a delta of -0.628100144 seconds
# Closest scan has a delta of 0.069797124 seconds
# mean_error: 0.7294399124215623 after 1 iterations
# Odometry pose in world: x=8.542476410637745, y=2.1642423463992975, theta=2.3761331112007205
# ICP pose in world: x=8.753861835015671, y=1.818129463816438, theta=2.2920971027837127
# Closest map is map_0012_1771970331425858800.png has a delta of -0.68156679 seconds
# Closest scan has a delta of 0.016330478 seconds
# mean_error: 0.7294399124215629 after 1 iterations
# Odometry pose in world: x=8.542458179987262, y=2.164259864337194, theta=2.376124194769789
# ICP pose in world: x=8.753861835015673, y=1.8181294638164391, theta=2.2920971027837127
# Closest map is map_0012_1771970331425858800.png has a delta of -0.717075299 seconds
# Closest scan has a delta of -0.019178031 seconds
# mean_error: 0.7294399124215621 after 1 iterations
# Odometry pose in world: x=8.542482124127499, y=2.1642368558490874, theta=2.3761146658210914
# ICP pose in world: x=8.753861835015671, y=1.8181294638164367, theta=2.2920971027837127
# Closest map is map_0012_1771970331425858800.png has a delta of -0.775764491 seconds
# Closest scan has a delta of 0.050142636 seconds
# mean_error: 0.7293944809541542 after 1 iterations
# Odometry pose in world: x=8.542463892461118, y=2.164254375409949, theta=2.3761057510238404
# ICP pose in world: x=8.753672237452715, y=1.818361803637651, theta=2.2921316212768814
# Closest map is map_0012_1771970331425858800.png has a delta of -0.822965183 seconds
# Closest scan has a delta of 0.002941944 seconds
# mean_error: 0.7293944809541543 after 1 iterations
# Odometry pose in world: x=8.5424878350474, y=2.1642313675657503, theta=2.376096223653694
# ICP pose in world: x=8.753672237452715, y=1.8183618036376459, theta=2.292131621276881
# Closest map is map_0012_1771970331425858800.png has a delta of -0.860645403 seconds
# Closest scan has a delta of -0.034738276 seconds
# mean_error: 0.7293944809541538 after 1 iterations
# Odometry pose in world: x=8.542469604199573, y=2.1642488869866954, theta=2.3760873104596816
# ICP pose in world: x=8.753672237452715, y=1.81836180363765, theta=2.2921316212768814
# Closest map is map_0012_1771970331425858800.png has a delta of -0.937221338 seconds
# Closest scan has a delta of 0.071778452 seconds
# mean_error: 0.7293528166448447 after 1 iterations
# Odometry pose in world: x=8.542493546006726, y=2.1642258790420232, theta=2.37607778446608
# ICP pose in world: x=8.753498249221927, y=1.8185754842937425, theta=2.2921633468107503
# Closest map is map_0012_1771970331425858800.png has a delta of -1.031253853 seconds
# Closest scan has a delta of -0.022254063 seconds
# mean_error: 0.7293528166448447 after 1 iterations
# Odometry pose in world: x=8.542475315067874, y=2.164243399197029, theta=2.376068872759066
# ICP pose in world: x=8.753498249221925, y=1.8185754842937414, theta=2.2921633468107503
# Closest map is map_0012_1771970331425858800.png has a delta of -1.111975627 seconds
# Closest scan has a delta of -0.102975837 seconds
# mean_error: 0.7293528166448455 after 1 iterations
# Odometry pose in world: x=8.542499255723623, y=2.164220391509809, theta=2.3760593481183583
# ICP pose in world: x=8.753498249221927, y=1.8185754842937396, theta=2.29216334681075
# Closest map is map_0012_1771970331425858800.png has a delta of -1.216511929 seconds
# Closest scan has a delta of 0.053862112 seconds
# mean_error: 0.729304364863961 after 1 iterations
# Odometry pose in world: x=8.542481025079566, y=2.1642379120280157, theta=2.376050437827806
# ICP pose in world: x=8.753295634645564, y=1.8188240906698125, theta=2.2922002710316205
# Closest map is map_0012_1771970331425858800.png has a delta of -1.270400438 seconds
# Closest scan has a delta of -2.6397e-05 seconds
# mean_error: 0.7293043648639622 after 1 iterations
# Odometry pose in world: x=8.542504964755388, y=2.1642149044336234, theta=2.376040914437993
# ICP pose in world: x=8.753295634645566, y=1.8188240906698114, theta=2.2922002710316205
# Closest map is map_0012_1771970331425858800.png has a delta of -1.344903154 seconds
# Closest scan has a delta of -0.074529113 seconds
# mean_error: 0.7293043648639599 after 1 iterations
# Odometry pose in world: x=8.542486734191053, y=2.164232425521641, theta=2.3760320054777644
# ICP pose in world: x=8.753295634645564, y=1.818824090669813, theta=2.292200271031621
# Closest map is map_0012_1771970331425858800.png has a delta of -1.448092972 seconds
# Closest scan has a delta of 0.094687759 seconds
# mean_error: 0.7292629784392534 after 1 iterations
# Odometry pose in world: x=8.542510672808024, y=2.1642094180960854, theta=2.376022483278938
# ICP pose in world: x=8.753121886474135, y=1.8190369345072654, theta=2.292231901236409
# Closest map is map_0012_1771970331425858800.png has a delta of -1.554028751 seconds
# Closest scan has a delta of -0.01124802 seconds
# mean_error: 0.7292629784392536 after 1 iterations
# Odometry pose in world: x=8.542492442396204, y=2.1642269396838874, theta=2.3760135755758727
# ICP pose in world: x=8.753121886474133, y=1.819036934507266, theta=2.292231901236409
# Closest map is map_0012_1771970331425858800.png has a delta of -1.590627444 seconds
# Closest scan has a delta of -0.047846713 seconds
# mean_error: 0.7292629784392547 after 1 iterations
# Odometry pose in world: x=8.542516379996874, y=2.16420393238643, theta=2.376004054493507
# ICP pose in world: x=8.753121886474135, y=1.819036934507261, theta=2.2922319012364087
# Closest map is map_0012_1771970331425858800.png has a delta of -1.702208211 seconds
# Closest scan has a delta of 0.015555715 seconds
# mean_error: 0.7292182510834135 after 1 iterations
# Odometry pose in world: x=8.542498149680553, y=2.164221454528743, theta=2.3759951479737693
# ICP pose in world: x=8.752934046480586, y=1.8192676930265184, theta=2.292266158194827
# Closest map is map_0012_1771970331425858800.png has a delta of -1.735814419 seconds
# Closest scan has a delta of -0.018050493 seconds
# mean_error: 0.7292182510834132 after 1 iterations
# Odometry pose in world: x=8.542522086253886, y=2.1641984473701363, theta=2.375985627945047
# ICP pose in world: x=8.752934046480583, y=1.819267693026518, theta=2.292266158194827
# Closest map is map_0012_1771970331425858800.png has a delta of -1.830758967 seconds
# Closest scan has a delta of 0.051942476 seconds
# mean_error: 0.7291772064954695 after 1 iterations
# Odometry pose in world: x=8.54250385604155, y=2.164215970058744, theta=2.375976722540268
# ICP pose in world: x=8.75276174507606, y=1.8194789500651452, theta=2.292297550222626
# Closest map is map_0012_1771970331425858800.png has a delta of -1.876734675 seconds
# Closest scan has a delta of 0.005966768 seconds
# mean_error: 0.7291772064954699 after 1 iterations
# Odometry pose in world: x=8.542527791604527, y=2.164192963022808, theta=2.37596720350154
# ICP pose in world: x=8.752761745076064, y=1.8194789500651447, theta=2.292297550222626
# Closest map is map_0012_1771970331425858800.png has a delta of -1.946708545 seconds
# Closest scan has a delta of -0.064007102 seconds
# mean_error: 0.7291772064954707 after 1 iterations
# Odometry pose in world: x=8.54250956147798, y=2.1642104862751452, theta=2.375958299145664
# ICP pose in world: x=8.75276174507606, y=1.8194789500651467, theta=2.292297550222626
# Closest map is map_0012_1771970331425858800.png has a delta of -1.978983072 seconds
# Closest scan has a delta of 0.059560598 seconds
# mean_error: 0.7291327919269576 after 1 iterations
# Odometry pose in world: x=8.542533496036848, y=2.164187479356009, theta=2.375948781038102
# ICP pose in world: x=8.752574090363364, y=1.8197089871614065, theta=2.2923317273178205
# Closest map is map_0012_1771970331425858800.png has a delta of -2.038571468 seconds
# Closest scan has a delta of -2.7798e-05 seconds
# mean_error: 0.7291327919269576 after 1 iterations
# Odometry pose in world: x=8.542515265993943, y=2.164205003174085, theta=2.3759398776686824
# ICP pose in world: x=8.752574090363362, y=1.8197089871614067, theta=2.2923317273178205
# Closest map is map_0012_1771970331425858800.png has a delta of -2.092642754 seconds
# Closest scan has a delta of -0.054099084 seconds
# mean_error: 0.7291327919269571 after 1 iterations
# Odometry pose in world: x=8.542539199561986, y=2.1641819963591074, theta=2.375930360435413
# ICP pose in world: x=8.75257409036336, y=1.819708987161405, theta=2.29233172731782
# Closest map is map_0012_1771970331425858800.png has a delta of -2.135015582 seconds
# Closest scan has a delta of 0.028484764 seconds
# mean_error: 0.7290953206484083 after 1 iterations
# Odometry pose in world: x=8.542520969596136, y=2.164199520749208, theta=2.3759214579927592
# ICP pose in world: x=8.75243425425458, y=1.819880347578549, theta=2.2923572944314308
# Closest map is map_0012_1771970331425858800.png has a delta of -2.177121234 seconds
# Closest scan has a delta of -0.013620888 seconds
# mean_error: 0.729095320648409 after 1 iterations
# Odometry pose in world: x=8.542544902184977, y=2.1641765140273383, theta=2.3759119415800143
# ICP pose in world: x=8.75243425425458, y=1.8198803475785514, theta=2.292357294431431
# Closest map is map_0012_1771970331425858800.png has a delta of -2.200684936 seconds
# Closest scan has a delta of -0.03718459 seconds
# mean_error: 0.7290953206484079 after 1 iterations
# Odometry pose in world: x=8.542526672294366, y=2.164194038991168, theta=2.37590304000739
# ICP pose in world: x=8.752434254254576, y=1.8198803475785499, theta=2.292357294431431
# Closest map is map_0012_1771970331425858800.png has a delta of -2.239709862 seconds
# Closest scan has a delta of 0.019455968 seconds
# mean_error: 0.7290548913698395 after 1 iterations
# Odometry pose in world: x=8.542550603917725, y=2.1641710323493317, theta=2.375893524363767
# ICP pose in world: x=8.752262531182685, y=1.8200912974249228, theta=2.2923886146480226
# Closest map is map_0012_1771970331425858800.png has a delta of -2.295907659 seconds
# Closest scan has a delta of -0.036741829 seconds
# mean_error: 0.7290548913698399 after 1 iterations
# Odometry pose in world: x=8.542532374100626, y=2.1641885578885107, theta=2.375884623607064
# ICP pose in world: x=8.752262531182685, y=1.8200912974249246, theta=2.292388614648023
# Closest map is map_0012_1771970331425858800.png has a delta of -2.365528761 seconds
# Closest scan has a delta of 0.070542921 seconds
# mean_error: 0.7290077595912918 after 1 iterations
# Odometry pose in world: x=8.542556304772281, y=2.1641655513135714, theta=2.375875108683693
# ICP pose in world: x=8.752043218153075, y=1.8203610250345783, theta=2.2924285394869948
# Closest map is map_0012_1771970331425858800.png has a delta of -2.391083987 seconds
# Closest scan has a delta of 0.044987695 seconds
# mean_error: 0.729007759591292 after 1 iterations
# Odometry pose in world: x=8.542538075028936, y=2.164183077427831, theta=2.3758662086914524
# ICP pose in world: x=8.752043218153071, y=1.8203610250345805, theta=2.292428539486995
# Closest map is map_0012_1771970331425858800.png has a delta of -2.467757861 seconds
# Closest scan has a delta of -0.031686179 seconds
# mean_error: 0.729007759591292 after 1 iterations
# Odometry pose in world: x=8.542562004763433, y=2.1641600709059086, theta=2.375856694441757
# ICP pose in world: x=8.752043218153073, y=1.8203610250345792, theta=2.2924285394869948
# Closest map is map_0012_1771970331425858800.png has a delta of -2.526723112 seconds
# Closest scan has a delta of 0.067581258 seconds
# mean_error: 0.7289640897750768 after 1 iterations
# Odometry pose in world: x=8.54254377509489, y=2.16417759759421, theta=2.3758477951649266
# ICP pose in world: x=8.751857611200606, y=1.8205891859786811, theta=2.292462410141343
# Closest map is map_0012_1771970331425858800.png has a delta of -2.576109015 seconds
# Closest scan has a delta of 0.018195355 seconds
# mean_error: 0.7289640897750772 after 1 iterations
# Odometry pose in world: x=8.542567703906997, y=2.164154591111207, theta=2.375838281544579
# ICP pose in world: x=8.751857611200608, y=1.820589185978679, theta=2.2924624101413427
# Closest map is map_0012_1771970331425858800.png has a delta of -2.629036018 seconds
# Closest scan has a delta of -0.034731648 seconds
# mean_error: 0.7289640897750768 after 1 iterations
# Odometry pose in world: x=8.542549474315408, y=2.164172118371453, theta=2.3758293829365016
# ICP pose in world: x=8.751857611200608, y=1.8205891859786802, theta=2.2924624101413427
# Closest map is map_0012_1771970331425858800.png has a delta of -2.682786174 seconds
# Closest scan has a delta of -0.088481804 seconds
# mean_error: 0.7289640897750767 after 1 iterations
# Odometry pose in world: x=8.542573402220182, y=2.164149111912983, theta=2.3758198699032755
# ICP pose in world: x=8.751857611200606, y=1.8205891859786831, theta=2.2924624101413427
# Closest map is map_0012_1771970331425858800.png has a delta of -2.762699662 seconds
# Closest scan has a delta of 0.020893943 seconds
# mean_error: 0.7289205510334523 after 1 iterations
# Odometry pose in world: x=8.542555172708429, y=2.1641666397423753, theta=2.3758109719194858
# ICP pose in world: x=8.751671775243762, y=1.8208176305111798, theta=2.292496320153833
# Closest map is map_0012_1771970331425858800.png has a delta of -2.8551561 seconds
# Closest scan has a delta of -0.071562495 seconds
# mean_error: 0.7289205510334523 after 1 iterations
# Odometry pose in world: x=8.542579099721022, y=2.1641436332939605, theta=2.375801459433185
# ICP pose in world: x=8.751671775243766, y=1.8208176305111758, theta=2.292496320153833
# Closest map is map_0012_1771970331425858800.png has a delta of -2.925127973 seconds
# Closest scan has a delta of 0.048902907 seconds
# mean_error: 0.7288805880187006 after 1 iterations
# Odometry pose in world: x=8.542560870292707, y=2.1641611616890133, theta=2.37579256203137
# ICP pose in world: x=8.751500199190598, y=1.8210283102442784, theta=2.292527605429187
# Closest map is map_0012_1771970331425858800.png has a delta of -3.029386439 seconds
# Closest scan has a delta of -0.055355559 seconds
# mean_error: 0.7288805880187005 after 1 iterations
# Odometry pose in world: x=8.542584796428322, y=2.1641381552361203, theta=2.3757830500537214
# ICP pose in world: x=8.751500199190597, y=1.821028310244275, theta=2.292527605429187
# Closest map is map_0012_1771970331425858800.png has a delta of -3.074046652 seconds
# Closest scan has a delta of -0.100015772 seconds
# mean_error: 0.728880588018701 after 1 iterations
# Odometry pose in world: x=8.542566567087595, y=2.1641556841928224, theta=2.375774153193599
# ICP pose in world: x=8.751500199190598, y=1.82102831024428, theta=2.2925276054291874
# Closest map is map_0012_1771970331425858800.png has a delta of -3.21816104 seconds
# Closest scan has a delta of 0.035703093 seconds
# mean_error: 0.7288374957995184 after 1 iterations
# Odometry pose in world: x=8.542590492361379, y=2.164132677720964, theta=2.375764641688167
# ICP pose in world: x=8.751315131094643, y=1.8212562165164687, theta=2.29256141359099
# Closest map is map_0012_1771970331425858800.png has a delta of -3.276057593 seconds
# Closest scan has a delta of -0.02219346 seconds
# mean_error: 0.7288374957995188 after 1 iterations
# Odometry pose in world: x=8.542572263112863, y=2.164150207234851, theta=2.375755745331398
# ICP pose in world: x=8.751315131094648, y=1.8212562165164679, theta=2.29256141359099

# %%
icp_result_df.head()
# Out:
#           x         y     theta  mean_error  initial_x  initial_y  \
# 0 -0.119677 -3.988704  0.048658    0.121002  -0.232880  -3.963869
# 1 -0.120027 -3.988739  0.048614    0.121000  -0.235369  -3.973322
# 2 -0.120027 -3.988739  0.048614    0.121000  -0.235369  -3.973322
# 3 -0.120027 -3.988739  0.048614    0.121000  -0.235369  -3.973322
# 4 -0.120027 -3.988739  0.048614    0.121000  -0.235369  -3.973322
#
#    initial_theta  mean_error_initial    odom_x    odom_y  odom_theta
# 0      -0.043960            0.241693 -0.259115 -3.987732   -0.094643
# 1      -0.044637            0.242389 -0.259147 -3.987729   -0.094644
# 2      -0.044637            0.242389 -0.259121 -3.987732   -0.094645
# 3      -0.044637            0.242389 -0.259153 -3.987729   -0.094647
# 4      -0.044637            0.242389 -0.259127 -3.987731   -0.094648

# %%
# plot mean error and initial mean error over time
plt.plot(odom["t_ns"].values, icp_result_df["mean_error"].values, label="Mean Error")
plt.plot(odom["t_ns"].values, icp_result_df["mean_error_initial"].values, label="Initial Mean Error")
plt.xlabel("Time (ns)")
plt.ylabel("Mean Error")
plt.title("ICP Mean Error Over Time")
plt.legend()
plt.grid()

# %%
# box plot of mean error and initial mean error
plt.figure(figsize=(6,4))
plt.boxplot([icp_result_df["mean_error_initial"].values, icp_result_df["mean_error"].values], labels=["Initial Mean Error", "Final Mean Error"])
plt.ylabel("Mean Error")
plt.title("Box Plot of ICP Mean Error")
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_178819/4046717026.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([icp_result_df["mean_error_initial"].values, icp_result_df["mean_error"].values], labels=["Initial Mean Error", "Final Mean Error"])

# %%
# plot icp and odom path over time
plt.plot(icp_result_df["x"].values, icp_result_df["y"].values, label="ICP Path")
plt.plot(icp_result_df["odom_x"].values, icp_result_df["odom_y"].values, label="Odometry Path")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("ICP and Odometry Paths")
plt.legend()
plt.grid()
plt.show()
